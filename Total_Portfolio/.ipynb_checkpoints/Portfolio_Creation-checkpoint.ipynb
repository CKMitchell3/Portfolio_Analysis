# %% [markdown]
# # **Total Portfolio Analysis**

# %% [markdown]
# ## Import Libraries and Dependencies

# %%
#Import your libraries and dependencies
import os
import pandas as pd
import yfinance as yf
import numpy as np
import pandas_datareader as pdr

# %matplotlib inline

# %% [markdown]
# ## Import Yahoo Stock Data

# %%
#Set your Datareader
yf.pdr_override()

#Set your tickers
tickers = ["SQ", "TSLA", "AAPL", "FB", "PYPL", "SHOP", "TDOC", "NVDA", "TWTR", "Z"]

#Set your portfolio dates
start = '2016-01-01'
end = '2021-05-06'

# %%
#Load your portfolio Dataframe into a variable
df = pdr.data.get_data_yahoo(tickers, start, end)
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
df.head()
# Out:
#             Adj Close                                                      \
#                  AAPL          FB       NVDA       PYPL       SHOP     SQ
# Date
# 2016-01-04  24.323219  102.220001  31.661398  34.750000  25.719999  12.16
# 2016-01-05  23.713696  102.730003  32.170021  34.310001  25.309999  11.51
# 2016-01-06  23.249626  102.970001  30.839788  33.980000  25.299999  11.52
# 2016-01-07  22.268383   97.919998  29.617151  33.130001  24.670000  11.16
# 2016-01-08  22.386133   97.330002  28.981380  32.689999  24.930000  11.31
#
#                                                     ...     Volume            \
#              TDOC       TSLA       TWTR          Z  ...       AAPL        FB
# Date                                                ...
# 2016-01-04  17.99  44.681999  22.559999  22.110001  ...  270597600  37912400
# 2016-01-05  19.50  44.686001  21.920000  21.990000  ...  223164000  23258200
# 2016-01-06  20.66  43.807999  21.389999  21.959999  ...  273829600  25096200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1344 entries, 2016-01-04 to 2021-05-05
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  1344 non-null   float64
#  1   (Adj Close, FB)    1344 non-null   float64
#  2   (Adj Close, NVDA)  1344 non-null   float64
#  3   (Adj Close, PYPL)  1344 non-null   float64
#  4   (Adj Close, SHOP)  1344 non-null   float64
#  5   (Adj Close, SQ)    1344 non-null   float64
#  6   (Adj Close, TDOC)  1344 non-null   float64
#  7   (Adj Close, TSLA)  1344 non-null   float64
#  8   (Adj Close, TWTR)  1344 non-null   float64
#  9   (Adj Close, Z)     1344 non-null   float64
#  10  (Close, AAPL)      1344 non-null   float64
#  11  (Close, FB)        1344 non-null   float64
#  12  (Close, NVDA)      1344 non-null   float64
#  13  (Close, PYPL)      1344 non-null   float64
#  14  (Close, SHOP)      1344 non-null   float64
# ...

# %%
total_portfolio = df[['Close']]

total_portfolio.head(10)
# Out:
#                 Close                                                      \
#                  AAPL          FB       NVDA       PYPL       SHOP     SQ
# Date
# 2016-01-04  26.337500  102.220001  32.369999  34.750000  25.719999  12.16
# 2016-01-05  25.677500  102.730003  32.889999  34.310001  25.309999  11.51
# 2016-01-06  25.174999  102.970001  31.530001  33.980000  25.299999  11.52
# 2016-01-07  24.112499   97.919998  30.280001  33.130001  24.670000  11.16
# 2016-01-08  24.240000   97.330002  29.629999  32.689999  24.930000  11.31
# 2016-01-11  24.632500   97.510002  29.680000  33.040001  23.870001  11.84
# 2016-01-12  24.990000   99.370003  30.180000  33.080002  23.740000  12.09
# 2016-01-13  24.347500   95.440002  29.260000  32.119999  21.379999  11.61
# 2016-01-14  24.879999   98.370003  28.670000  32.869999  20.639999  10.82
# 2016-01-15  24.282499   94.970001  27.110001  32.310001  19.889999  10.27
#
#
#                  TDOC       TSLA       TWTR          Z
# Date
# ...

# %%
total_portfolio.columns = ["AAPL", "FB", "NVDA", "PYPL", "SHOP", "SQ", "TDOC", "TSLA", "TWTR", "Z"]

total_portfolio.head(10)
# Out:
#                  AAPL          FB       NVDA       PYPL       SHOP     SQ  \
# Date
# 2016-01-04  26.337500  102.220001  32.369999  34.750000  25.719999  12.16
# 2016-01-05  25.677500  102.730003  32.889999  34.310001  25.309999  11.51
# 2016-01-06  25.174999  102.970001  31.530001  33.980000  25.299999  11.52
# 2016-01-07  24.112499   97.919998  30.280001  33.130001  24.670000  11.16
# 2016-01-08  24.240000   97.330002  29.629999  32.689999  24.930000  11.31
# 2016-01-11  24.632500   97.510002  29.680000  33.040001  23.870001  11.84
# 2016-01-12  24.990000   99.370003  30.180000  33.080002  23.740000  12.09
# 2016-01-13  24.347500   95.440002  29.260000  32.119999  21.379999  11.61
# 2016-01-14  24.879999   98.370003  28.670000  32.869999  20.639999  10.82
# 2016-01-15  24.282499   94.970001  27.110001  32.310001  19.889999  10.27
#
#                  TDOC       TSLA       TWTR          Z
# Date
# 2016-01-04  17.990000  44.681999  22.559999  22.110001
# ...

# %%
total_portfolio.columns = pd.MultiIndex.from_tuples(
    zip(total_portfolio.columns, ['close','close', 'close','close', 'close','close', 'close','close', 'close','close']
        ))

total_portfolio.head()
# Out:
#                  AAPL          FB       NVDA       PYPL       SHOP     SQ  \
#                 close       close      close      close      close  close
# Date
# 2016-01-04  26.337500  102.220001  32.369999  34.750000  25.719999  12.16
# 2016-01-05  25.677500  102.730003  32.889999  34.310001  25.309999  11.51
# 2016-01-06  25.174999  102.970001  31.530001  33.980000  25.299999  11.52
# 2016-01-07  24.112499   97.919998  30.280001  33.130001  24.670000  11.16
# 2016-01-08  24.240000   97.330002  29.629999  32.689999  24.930000  11.31
#
#              TDOC       TSLA       TWTR          Z
#             close      close      close      close
# Date
# 2016-01-04  17.99  44.681999  22.559999  22.110001
# 2016-01-05  19.50  44.686001  21.920000  21.990000
# 2016-01-06  20.66  43.807999  21.389999  21.959999
# 2016-01-07  20.18  43.130001  20.260000  21.500000
# 2016-01-08  19.17  42.200001  19.980000  22.100000

# %%
total_portfolio.count()
# Out:
# AAPL  close    1344
# FB    close    1344
# NVDA  close    1344
# PYPL  close    1344
# SHOP  close    1344
# SQ    close    1344
# TDOC  close    1344
# TSLA  close    1344
# TWTR  close    1344
# Z     close    1344
# dtype: int64

# %% [markdown]
# ## Portfolio Volume Analysis

# %%
portfolio_volumes = df[['Volume']]

portfolio_volumes.head(10)
# Out:
#                Volume                                                         \
#                  AAPL        FB      NVDA      PYPL    SHOP       SQ    TDOC
# Date
# 2016-01-04  270597600  37912400   8951900  12287700  601800  2751500  186100
# 2016-01-05  223164000  23258200  12256800  11227700  418200  2352800  373300
# 2016-01-06  273829600  25096200  11233600   8441300  256600  1850600  509600
# 2016-01-07  324377600  45172900  16132600  11041100  416000  1636000  277400
# 2016-01-08  283192000  35402300   9961800   7848800  137400   587300  192700
# 2016-01-11  198957600  29932400  10234300   8937400  294500  1676900  191400
# 2016-01-12  196616800  28395400  11733900   7854000  369800  2136100  262000
# 2016-01-13  249758400  33410600  12041800   8069400  510500  2095200  474000
# 2016-01-14  252680400  48658600  15005900   7749500  813700  1604900  304400
# 2016-01-15  319335600  46132800  21036300  12174400  921200  1203700  200400
#
#
# ...

# %%
portfolio_volumes.columns = ["AAPL", "FB", "NVDA", "PYPL", "SHOP", "SQ", "TDOC", "TSLA", "TWTR", "Z"]

# %%
portfolio_volumes.columns = pd.MultiIndex.from_tuples(
    zip(portfolio_volumes.columns, ['Volume','Volume', 'Volume','Volume', 'Volume','Volume', 'Volume','Volume', 'Volume','Volume']
        ))

portfolio_volumes.head()
# Out:
#                  AAPL        FB      NVDA      PYPL    SHOP       SQ    TDOC  \
#                Volume    Volume    Volume    Volume  Volume   Volume  Volume
# Date
# 2016-01-04  270597600  37912400   8951900  12287700  601800  2751500  186100
# 2016-01-05  223164000  23258200  12256800  11227700  418200  2352800  373300
# 2016-01-06  273829600  25096200  11233600   8441300  256600  1850600  509600
# 2016-01-07  324377600  45172900  16132600  11041100  416000  1636000  277400
# 2016-01-08  283192000  35402300   9961800   7848800  137400   587300  192700
#
#                 TSLA      TWTR        Z
#               Volume    Volume   Volume
# Date
# 2016-01-04  34135500  15325000  1504400
# 2016-01-05  15934000  17077700  1252600
# 2016-01-06  18895500  14033600  1089100
# 2016-01-07  17771500  20759800  1178900
# 2016-01-08  18140500  21832300  1056500

# %% [markdown]
# ### Year-To-Date Volume Analysis

# %%
ytd_portfolio_volumes = portfolio_volumes.loc['2021']

ytd_portfolio_volumes.head(10)
# Out:
#                  AAPL        FB      NVDA     PYPL     SHOP        SQ  \
#                Volume    Volume    Volume   Volume   Volume    Volume
# Date
# 2021-01-04  143301900  15106100  14016000  8148700  1644900   9838400
# 2021-01-05   97664900   9871600   8069000  5047800   905500   9699400
# 2021-01-06  155088000  24354100  14510600  9211700  1268700  12003500
# 2021-01-07  109578200  15789800  11537000  7107900  1376500  10214200
# 2021-01-08  105158200  18528300   7313200  6767700  1378100   9102100
# 2021-01-11  100384500  30412300  12958600  5073100  1110800  14107500
# 2021-01-12   91951100  26383500   7286900  4136600   902200   8437900
# 2021-01-13   88636800  19528900   5250700  7354900   693800   7601400
# 2021-01-14   90221800  29739400   7078000  6976700  1183800   6706500
# 2021-01-15  111598500  24942900   6944500  8373300   893300   7049200
#
#                TDOC      TSLA      TWTR        Z
#              Volume    Volume    Volume   Volume
# Date
# ...

# %%
ytd_portfolio_volumes.tail()
# Out:
#                  AAPL        FB      NVDA     PYPL     SHOP       SQ  \
#                Volume    Volume    Volume   Volume   Volume   Volume
# Date
# 2021-04-29  151101000  56526800   4329900  5663700  1652600  6592800
# 2021-04-30  109713200  26322000   5038300  6589400  1583700  6181200
# 2021-05-03   75135100  18719500   5097800  7522000  1398300  5268800
# 2021-05-04  137564700  24032600  10133100  9217300  2093300  9123600
# 2021-05-05   84000900  15577600   7300600  9507300   651100  3792900
#
#                 TDOC      TSLA      TWTR        Z
#               Volume    Volume    Volume   Volume
# Date
# 2021-04-29  12156900  28845400  31017700  1729100
# 2021-04-30   4084400  40686400  88212500  2251000
# 2021-05-03   4680000  27043100  79649000  3427200
# 2021-05-04   6137400  29739300  30404500  6534000
# 2021-05-05   2608700  21901900  11549700  7741700

# %%
ytd_portfolio_volumes.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Amount of shares are calculated based on the closing price of each stock on January 4, 2016
#Each stock has $10,000 worth

#AAPL closing price = $24.36
#FB closing price = $102.22
#NVDA closing price = $31.66
#PYPL closing price = $34.75
#SHOP closing price = $25.72
#SQ closing price = $12.16
#TDOC closing price = $17.99
#TSLA closing price = $44.68
#TWTR closing price = $22.56
#Z closing price = $22.11

aapl_shares = 411
fb_shares = 98
nvda_shares = 316
pypl_shares = 288
shop_shares = 389
sq_shares = 823
tdoc_shares = 556
tsla_shares = 224
twtr_shares = 444
z_shares = 453

# %%
total_portfolio.to_csv('Total_Portfolio.csv')
