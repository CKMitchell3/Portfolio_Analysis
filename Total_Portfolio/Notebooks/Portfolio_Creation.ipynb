# %% [markdown]
# # **Portfolio Creation**

# %% [markdown]
# ## Import Libraries and Dependencies

# %%
#Import your libraries and dependencies
import os
import pandas as pd
import yfinance as yf
import numpy as np
import pandas_datareader as pdr

# %matplotlib inline

# %% [markdown]
# ## Import Yahoo Stock Portfolio Data

# %%
#Set your Datareader
yf.pdr_override()

#Set your tickers
tickers = ["SQ", "TSLA", "AAPL", "FB", "PYPL", "SHOP", "TDOC", "NVDA", "TWTR", "Z"]

#Set your portfolio dates
start = '2016-01-01'
end = '2021-05-20'

# %%
#Load your portfolio Dataframe into a variable
df = pdr.data.get_data_yahoo(tickers, start, end)
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
df.tail()
# Out:
#              Adj Close                                                   \
#                   AAPL          FB        NVDA        PYPL         SHOP
# Date
# 2021-05-13  124.970001  305.260010  546.609985  240.800003  1047.770020
# 2021-05-14  127.449997  315.940002  569.719971  246.289993  1085.010010
# 2021-05-17  126.269997  315.459991  566.619995  244.360001  1096.390015
# 2021-05-18  124.849998  309.959991  560.630005  243.210007  1133.359985
# 2021-05-19  124.690002  313.589996  562.630005  244.630005  1170.390015
#
#                                                                        ...  \
#                     SQ        TDOC        TSLA       TWTR           Z  ...
# Date                                                                   ...
# 2021-05-13  197.130005  132.710007  571.690002  50.110001  107.099998  ...
# 2021-05-14  207.850006  139.679993  589.739990  51.730000  111.879997  ...
# 2021-05-17  202.919998  137.360001  576.830017  52.599998  110.169998  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1354 entries, 2016-01-04 to 2021-05-19
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  1354 non-null   float64
#  1   (Adj Close, FB)    1354 non-null   float64
#  2   (Adj Close, NVDA)  1354 non-null   float64
#  3   (Adj Close, PYPL)  1354 non-null   float64
#  4   (Adj Close, SHOP)  1354 non-null   float64
#  5   (Adj Close, SQ)    1354 non-null   float64
#  6   (Adj Close, TDOC)  1354 non-null   float64
#  7   (Adj Close, TSLA)  1354 non-null   float64
#  8   (Adj Close, TWTR)  1354 non-null   float64
#  9   (Adj Close, Z)     1354 non-null   float64
#  10  (Close, AAPL)      1354 non-null   float64
#  11  (Close, FB)        1354 non-null   float64
#  12  (Close, NVDA)      1354 non-null   float64
#  13  (Close, PYPL)      1354 non-null   float64
#  14  (Close, SHOP)      1354 non-null   float64
# ...

# %%
# Separate the Adjusted Closing Prices

stock_portfolio = df[['Adj Close']]

stock_portfolio.head(10)
# Out:
#             Adj Close                                                      \
#                  AAPL          FB       NVDA       PYPL       SHOP     SQ
# Date
# 2016-01-04  24.323219  102.220001  31.661398  34.750000  25.719999  12.16
# 2016-01-05  23.713696  102.730003  32.170021  34.310001  25.309999  11.51
# 2016-01-06  23.249626  102.970001  30.839788  33.980000  25.299999  11.52
# 2016-01-07  22.268383   97.919998  29.617151  33.130001  24.670000  11.16
# 2016-01-08  22.386133   97.330002  28.981380  32.689999  24.930000  11.31
# 2016-01-11  22.748621   97.510002  29.030289  33.040001  23.870001  11.84
# 2016-01-12  23.078775   99.370003  29.519341  33.080002  23.740000  12.09
# 2016-01-13  22.485413   95.440002  28.619478  32.119999  21.379999  11.61
# 2016-01-14  22.977186   98.370003  28.042391  32.869999  20.639999  10.82
# 2016-01-15  22.425385   94.970001  26.516548  32.310001  19.889999  10.27
#
#
#                  TDOC       TSLA       TWTR          Z
# Date
# ...

# %%
# Rename your columns

stock_portfolio.columns = ["AAPL", "FB", "NVDA", "PYPL", "SHOP", "SQ", "TDOC", "TSLA", "TWTR", "Z"]

stock_portfolio.head(10)
# Out:
#                  AAPL          FB       NVDA       PYPL       SHOP     SQ
# 2021-05-17   74244600  15401300  5424500   5185100  1086000  12133800
# 2021-05-18   63342900  14522400  4656400   4726800  1915800  10088000
# 2021-05-19   92499900  19089800  8587500   7206300  1939900  16391100
#
#                TDOC      TSLA      TWTR        Z
# Date
# 2021-05-06  5164000  27784600  19586900  5767300
# 2021-05-07  4505000  23422100  21719200  4216400
# ...

# %% [markdown]
# ### Year-To-Date Volume Analysis

# %%
ytd_stock_portfolio_volumes = stock_portfolio_volumes.loc['2021']

ytd_stock_portfolio_volumes.head(10)
# Out:
#                  AAPL        FB      NVDA     PYPL     SHOP        SQ  \
# Date
# 2021-01-04  143301900  15106100  14016000  8148700  1644900   9838400
# 2021-01-05   97664900   9871600   8069000  5047800   905500   9699400
# 2021-01-06  155088000  24354100  14510600  9211700  1268700  12003500
# 2021-01-07  109578200  15789800  11537000  7107900  1376500  10214200
# 2021-01-08  105158200  18528300   7313200  6767700  1378100   9102100
# 2021-01-11  100384500  30412300  12958600  5073100  1110800  14107500
# 2021-01-12   91951100  26383500   7286900  4136600   902200   8437900
# 2021-01-13   88636800  19528900   5250700  7354900   693800   7601400
# 2021-01-14   90221800  29739400   7078000  6976700  1183800   6706500
# 2021-01-15  111598500  24942900   6944500  8373300   893300   7049200
#
#                TDOC      TSLA      TWTR        Z
# Date
# 2021-01-04  2552800  48638200  12231600  1878100
# 2021-01-05  2086200  32245200   8317200  2757500
# ...

# %%
ytd_stock_portfolio_volumes.tail()
# Out:
#                  AAPL        FB     NVDA     PYPL     SHOP        SQ     TDOC  \
# Date
# 2021-05-13  105861300  18079200  7135100  7274000  1554900  21397100  5316700
# 2021-05-14   81806500  19230600  6453700  6721400  1053800  11479100  3390600
# 2021-05-17   74244600  15401300  5424500  5185100  1086000  12133800  2921100
# 2021-05-18   63342900  14522400  4656400  4726800  1915800  10088000  3009700
# 2021-05-19   92499900  19089800  8587500  7206300  1939900  16391100  2497500
#
#                 TSLA      TWTR        Z
# Date
# 2021-05-13  44184900  14303900  3722000
# 2021-05-14  33230600   9821900  2640400
# 2021-05-17  32390400  21351700  2481900
# 2021-05-18  36830600  23612300  2579500
# 2021-05-19  39471500  21547600  2744700

# %%
ytd_stock_portfolio_volumes.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Import Yahoo Stock Index Data

# %%
tickers_2 = ["^DJI", "^GSPC", "^IXIC", "^TNX"]

start_2 = '2016-01-01'
end_2 = '2021-05-20'

# %%
df_2 = pdr.data.get_data_yahoo(tickers_2, start_2, end_2)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df_2.head(10)
# Out:
#                Adj Close                                          Close  \
#                     ^DJI        ^GSPC        ^IXIC   ^TNX          ^DJI
# Date
# 2016-01-04  17148.939453  2012.660034  4903.089844  2.245  17148.939453
# 2016-01-05  17158.660156  2016.709961  4891.430176  2.248  17158.660156
# 2016-01-06  16906.509766  1990.260010  4835.759766  2.177  16906.509766
# 2016-01-07  16514.099609  1943.089966  4689.430176  2.153  16514.099609
# 2016-01-08  16346.450195  1922.030029  4643.629883  2.130  16346.450195
# 2016-01-11  16398.570312  1923.670044  4637.990234  2.158  16398.570312
# 2016-01-12  16516.220703  1938.680054  4685.919922  2.102  16516.220703
# 2016-01-13  16151.410156  1890.280029  4526.060059  2.066  16151.410156
# 2016-01-14  16379.049805  1921.839966  4615.000000  2.098  16379.049805
# 2016-01-15  15988.080078  1880.329956  4488.419922  2.033  15988.080078
#
#                                                      High               ...  \
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1355 entries, 2016-01-04 to 2021-05-20
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, ^DJI)   1354 non-null   float64
#  1   (Adj Close, ^GSPC)  1354 non-null   float64
#  2   (Adj Close, ^IXIC)  1354 non-null   float64
#  3   (Adj Close, ^TNX)   1343 non-null   float64
#  4   (Close, ^DJI)       1354 non-null   float64
#  5   (Close, ^GSPC)      1354 non-null   float64
#  6   (Close, ^IXIC)      1354 non-null   float64
#  7   (Close, ^TNX)       1343 non-null   float64
#  8   (High, ^DJI)        1354 non-null   float64
#  9   (High, ^GSPC)       1354 non-null   float64
#  10  (High, ^IXIC)       1354 non-null   float64
#  11  (High, ^TNX)        1343 non-null   float64
#  12  (Low, ^DJI)         1354 non-null   float64
#  13  (Low, ^GSPC)        1354 non-null   float64
#  14  (Low, ^IXIC)        1354 non-null   float64
# ...

# %%
# Separate the Adjusted Closing Prices

index_portfolio = df_2[['Adj Close']]

index_portfolio.tail(10)
# Out:
#                Adj Close
#                     ^DJI        ^GSPC         ^IXIC   ^TNX
# Date
# 2021-05-07  34777.761719  4232.600098  13752.240234  1.577
# 2021-05-10  34742.820312  4188.430176  13401.860352  1.602
# 2021-05-11  34269.160156  4152.100098  13389.429688  1.624
# 2021-05-12  33587.660156  4063.040039  13031.679688  1.695
# 2021-05-13  34021.449219  4112.500000  13124.990234  1.668
# 2021-05-14  34382.128906  4173.850098  13429.980469  1.635
# 2021-05-17  34327.789062  4163.290039  13379.049805  1.640
# 2021-05-18  34060.660156  4127.830078  13303.639648  1.642
# 2021-05-19  33896.039062  4115.680176  13299.740234  1.683
# 2021-05-20           NaN          NaN           NaN  1.634

# %%
index_portfolio.columns = ['DJIA', 'S&P500', 'NASDAQ', '10Yr Yield']

index_portfolio.head(10)
# Out:
#                     DJIA       S&P500       NASDAQ  10Yr Yield
# Date
# 2016-01-04  17148.939453  2012.660034  4903.089844       2.245
# 2016-01-05  17158.660156  2016.709961  4891.430176       2.248
# 2016-01-06  16906.509766  1990.260010  4835.759766       2.177
# 2016-01-07  16514.099609  1943.089966  4689.430176       2.153
# 2016-01-08  16346.450195  1922.030029  4643.629883       2.130
# 2016-01-11  16398.570312  1923.670044  4637.990234       2.158
# 2016-01-12  16516.220703  1938.680054  4685.919922       2.102
# 2016-01-13  16151.410156  1890.280029  4526.060059       2.066
# 2016-01-14  16379.049805  1921.839966  4615.000000       2.098
# 2016-01-15  15988.080078  1880.329956  4488.419922       2.033

# %%
index_portfolio.count()
# Out:
# DJIA          1354
# S&P500        1354
# NASDAQ        1354
# 10Yr Yield    1343
# dtype: int64

# %% [markdown]
# ## Create CSV Files for your Dataframes

# %%
stock_portfolio.to_csv('Stock_Portfolio_Prices.csv')

# %%
stock_portfolio_volumes.to_csv('Stock_Portfolio_Volumes.csv')

# %%
index_portfolio.to_csv('Index_Closing_Prices.csv')
